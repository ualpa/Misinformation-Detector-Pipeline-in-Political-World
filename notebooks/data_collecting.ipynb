# %% [markdown]
# Libraries instalation
#
# pip install requests pandas python-dotenv newsapi-python jupyter
#
# source .venv/bin/activate
#
# https://newsapi.org/account

# %% [markdown]
# 1. Setup

# %%
import requests
import pandas as pd
import json
from dotenv import load_dotenv, find_dotenv
import os

load_dotenv(find_dotenv(), override=True) 
API_KEY = os.getenv("NEWS_API_KEY")

# %% [markdown]
# 2. Fetch political articles

# %%
url = "https://newsapi.org/v2/everything"

params = {
    "q": "politics misinformation fake news",
    "language": "en",
    "sortBy": "publishedAt",
    "pageSize": 100,
    "apiKey": API_KEY
}

response = requests.get(url, params=params)
data = response.json()

print(f"Status: {data['status']}")
print(f"Total articole găsite: {data['totalResults']}")
# Out:
# Status: ok
# Total articole găsite: 31

# %% [markdown]
# 3. Data visualization

# %%
articles = data["articles"]
df = pd.DataFrame(articles)

df[["source", "title", "description", "publishedAt", "url"]].head()
# Out:
#                                               source  \
# 0  {'id': None, 'name': 'The New York Review of B...
# 1              {'id': None, 'name': 'Khabarhub.com'}
# 2                {'id': None, 'name': 'Skeptic.com'}
# 3                {'id': None, 'name': 'Skeptic.com'}
# 4                 {'id': 'news24', 'name': 'News24'}
#
#                                                title  \
# 0                             The Sage of Washington
# 1                         Today’s News in a Nutshell
# 2            Conspiracy Inc.: The New Media Disorder
# 3            Conspiracy Inc.: The New Media Disorder
# 4  News24 | Lizette Rabe | In 2026, the fight for...
#
#                                          description           publishedAt  \
# 0  Walter Lippmann was the most influential polit...  2026-05-07T12:00:00Z
# 1  KATHMANDU: Khabarhub brings you key developmen...  2026-05-04T16:15:38Z
# 2  Ashley Rindsberg traces how the collapse of tr...  2026-05-03T17:42:54Z
# 3  Ashley Rindsberg traces how the collapse of tr...  2026-05-03T16:17:30Z
# 4  Truth is the first casualty of war, and we’re ...  2026-05-02T09:51:27Z
#
#                                                  url
# 0  https://www.nybooks.com/articles/2026/05/28/th...
# 1      https://english.khabarhub.com/2026/04/547124/
# 2  https://www.skeptic.com/article/conspiracy-car...
# 3  https://www.skeptic.com/article/conspiracy-inc...
# 4  https://www.news24.com/opinions/columnists/liz...

# %% [markdown]
# 4. Saving the raw data

# %%
df.to_csv("../data/raw/articles_raw.csv", index=False)
print(f"Salvate {len(df)} articole în data/raw/articles_raw.csv")
# Out:
# Salvate 30 articole în data/raw/articles_raw.csv
